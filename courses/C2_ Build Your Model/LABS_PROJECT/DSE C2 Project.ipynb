# %% [markdown]
# # DSE Course 2 Project
#
# **Instructor**: Wesley Beckner
#
# **Contact**: wesleybeckner@gmail.com
#
# <br>
#
# ---
#
# <br>
#
# Broad Objectives:
#
#  1) structure your code into OOP
#   - package functions and code into object oriented code
#   - create a pythonic package directory structure
# <br>
#
#
# **Optionally**
#
#  2) incorporate any new preprocessing/learning techniques we've covered
#
#
#
#
# ```
# ├── <pacakgename>
# │   ├── __init__.py
# │   ├── <packagename>.py
# │   ├── data
# │   │   ├── <datafile1>.h5
# │   │   └── <datafile2>.csv
# │   ├── <helperstuff>.py
# │   └── version.py
# ├── LICENSE
# ├── README.md
# ├── examples
# │   ├── README.ipynb
# └── setup.py
# ```
# organize project into a GitHub Repository
#
# TO INCLUDE:
#
# * `LICENSE`
# * `README.md`
# * `requirements.txt`
# * `<yourpackage>.py`
# * `<yourpackage>_demo.ipynb`
#
# TO MODIFY:
#
# * `setup.py`
# * `version.py`
# * `__init__.py`
#
# BE SURE TO INCLUDE IN YOUR PACKAGE
#
# * DOCSTRINGS!!!! (follow sklearn/pandas/numpy examples)
# * `<yourpackage>_demo.ipynb`!!! with markdown explanations!!!
#
# IF YOU THINK YOU ARE DONE
#
# * Practice raising issues in github
# * Practice installing your own package
